# %% [markdown]
# <img src="Python-Logo.png" alt="Girl in a jacket" width="300" height="300" class="topleft">

# %% [markdown]
# # Getting Started with Python:
#
# Python is a general-purpose interpreted, interactive, object-oriented, and high-level programming language. It was created by Guido van Rossum during 1985- 1990.
#
# ## Why to Learn Python?
#
# Python is designed to be highly readable. It uses English keywords frequently where as other languages use punctuation, and it has fewer syntactical constructions than other languages.
#
# - Python is Interpreted
# - Python is Interactive
# - Python is Object-Oriented
# - Python is a Beginner's Language

# %% [markdown]
# ## Hello World using Python
# Just to give you a little excitement about Python, I'm going to give you a small conventional Python Hello World program

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Python Indentation
#
# Indentation refers to the spaces at the beginning of a code line.
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# Python uses indentation to indicate a block of code.

# %%
if 4 > 5:
  print("Four is greater than Five!")

# %% [markdown]
# if 5 > 2:
# print("Five is greater than two!")

# %% [markdown]
# ## Python Variables
# In Python, variables are created when you assign a value to it
#
# - Python has no command for declaring a variable.

# %%
x = 5
y = "Hello, World!"
print(x)
print(type(x))
x="Python"
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>
# Python
# <class 'str'>

# %% [markdown]
# ## Comments
# - Comments can be used to explain Python code.
# - Comments can be used to make the code more readable.
# - Comments can be used to prevent execution when testing code.
#
# Comments starts with a #, and Python will ignore them:

# %%
#This is a comment.
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# - Comments can be placed at the end of a line, and Python will ignore the rest of the line:

# %%
print("Hello, World!") #This is a comment
# Out:
# Hello, World!

# %%
# line
# line 2
# programming

# %% [markdown]
# ## Multi Line Comments

# %%
"""
This is a comment
written in
more than just one line
programming
"""
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 1. DATA TYPES

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %% [raw]
# Fourtypes which we mostly used
#
# -> String (Example: "Abdul Ahad", 'IBA')
# -> Integer (Example: 12, 100, 3)
# -> Float (Example: 1.2, 12.5, 111.885)
# -> Boolean (True or False)

# %% [markdown]
# <a name='variables'></a>Variables
# ===
# A variable holds a value.
#
# Python automatically assign type to a variable based on the values

# %% [markdown]
# <a name='example'></a>Example
# ---

# %%
message = "Hello Python world!"
print(message)
#type(message)
# Out:
# Hello Python world!

# %% [markdown]
# A variable holds a value. You can change the value of a variable at any point.

# %%
message = "Hello Python world!"
print(message)

python_string = "Python is my favorite language!"
print(python_string)
# Out:
# Hello Python world!
# Python is my favorite language!

# %% [markdown]
# <a name='naming_rules'></a>Naming rules
# ---
# - Variables can only contain letters, numbers, and underscores. Variable names can start with a letter or an underscore, but can not start with a number.
# - Spaces are not allowed in variable names, so we use underscores instead of spaces. For example, use student_name instead of "student name".
# - You cannot use [Python keywords](http://docs.python.org/3/reference/lexical_analysis.html#keywords) as variable names.
# - Variable names should be descriptive, without being too long. For example mc_wheels is better than just "wheels", and number_of_wheels_on_a_motorycle.
# - Be careful about using the lowercase letter l and the uppercase letter O in places where they could be confused with the numbers 1 and 0.

# %% [markdown]
# ## Escape Sequence in Python
#
# ![Screenshot%202022-02-16%20194709.png](attachment:Screenshot%202022-02-16%20194709.png)

# %%
print("Ahad\\nImtiaz")
# Out:
# Ahad\nImtiaz

# %% [markdown]
# print(""Hello World"")   # Gives Error

# %%
print(" "string"")
# Out:
#   Input In [15]
#     print(" "string"")
#              ^
# SyntaxError: invalid syntax

# %%
print(" \"Hello World\" ")
# Out:
#  "Hello World"

# %%
print("'Hello World'")
# Out:
# 'Hello World'

# %%
print(" \'Hello World\' ")
# Out:
#  'Hello World'

# %%
print("DSC\nIBA")
# Out:
# DSC
# IBA

# %%
print("DSC\tIBA")
# Out:
# DSC	IBA

# %%
print("Today is a lovely Day. Everone is welcome in todays session")
# Out:
# Today is a lovely Day. Everone is welcome in todays session

# %%
print("Today is a lovely   Day. Everone is welcome in todays session".split())
# Out:
# ['Today', 'is', 'a', 'lovely', 'Day.', 'Everone', 'is', 'welcome', 'in', 'todays', 'session']

# %%
print(*"Today is a lovely   Day. Everone is welcome in todays session".split())
# Out:
# Today is a lovely Day. Everone is welcome in todays session

# %%
print(*"Today is a lovely   Day. Everone is welcome in todays session".split(), sep = "\n")
# Out:
# Today
# is
# a
# lovely
# Day.
# Everone
# is
# welcome
# in
# todays
# session

# %%
print(*"Today is a lovely Day. Everone is welcome in todays session", sep = "\n")
# Out:
# T
# o
# d
# a
# y
#
# i
# s
#
# a
#
# l
# o
# v
# e
# l
# y
#
# D
# a
# y
# .
#
# E
# v
# e
# r
# o
# n
# e
#
# i
# s
#
# w
# e
# l
# c
# o
# m
# e
#
# i
# n
#
# t
# o
# d
# a
# y
# s
#
# s
# e
# s
# s
# i
# o
# n

# %%
Name = "Abdul Ahad"
age = 20

print("My age is "+ str(age) + "My name is " + Name )
print("My Name is {} and age is {}".format(Name,age))
# Out:
# My age is 20My name is Abdul Ahad
# My Name is Abdul Ahad and age is 20

# %% [markdown]
# Strings
# ===
# Strings are sets of characters. Strings are easier to understand by looking at some examples.

# %% [markdown]
# <a name='single_double_quotes'></a>Single and double quotes
# ---
# Strings are contained by either single or double quotes.

# %%
my_string = "This is a double-quoted string."
my_string2 = 'This is a single-quoted string.'
print(my_string)
print(my_string2)
# Out:
# This is a double-quoted string.
# This is a single-quoted string.

# %% [markdown]
# This lets us make strings that contain quotations.

# %%
quote = "Linus Torvalds once said, \'Any program is only as good as it is useful.'"
print(quote)
# Out:
# Linus Torvalds once said, 'Any program is only as good as it is useful.'

# %% [markdown]
# ### Multiline Strings
#
# In case we need to create a multiline string, there is the **triple-quote** to the rescue:
# `'''`

# %%
multiline_string = ''' 
This is a string where I... 
...can confortably write on multiple lines
without worring about to use the escape character "\\" as in
the previsou example. 
As you'll see, the original string formatting is preserved.
'''

print(multiline_string)
# Out:
#
# This is a string where I
# can confortably write on multiple lines
# without worring about to use the escape character "\" as in
# the previsou example.
# As you'll see, the original string formatting is preserved.

# %%
single_line = " this is a string\nand this is new line"

print(single_line)
# Out:
#  this is a string
# and this is new line

# %% [markdown]
# <a name='changing_case'></a>Changing case
# ---
# You can easily change the case of a string, to present it the way you want it to look.

# %%
first_name = 'abdul aHAd'

print(first_name)
print(first_name.title())
# Out:
# abdul aHAd
# Abdul Ahad

# %% [markdown]
# It is often good to store data in lower case, and then change the case as you want to for presentation. This catches some TYpos. It also makes sure that 'eric', 'Eric', and 'ERIC' are not considered three different people.
#
# Some of the most common cases are lower, title, and upper.

# %%
first_name = 'eric'

#print(first_name)
first_name = first_name.title()
#print(first_name.capitalize())
#print(first_name)
print(first_name.upper()) #string first name doesnt change
print(first_name)
first_name_titled = 'ERic'
print(first_name_titled.lower())
# Out:
# ERIC
# Eric
# eric

# %% [markdown]
# **Note**: Please notice that the original strings remain **always** unchanged
#
# - **Strings** are **Immutable**

# %%
print(first_name)
print(first_name_titled)
# Out:
# Eric
# Eric

# %% [markdown]
# # Swapping two values

# %%
a = 6
b = 5

print("a was {} and b was {}".format(a,b))

temp = a
a=b
b=temp

print("now a is {} and b is {}".format(a,b))
# Out:
# a was 6 and b was 5
# now a is 5 and b is 6

# %% [markdown]
# #

# %%
a = 6
b = 5

print("a was {} and b was {}".format(a,b))

#this doesnt work when the variable is not string
#print("a was " + a + " and b was " + b)

a,b=b,a
print("now a is {} and b is {}".format(a,b))
# Out:
# a was 6 and b was 5
# now a is 5 and b is 6

# %% [markdown]
# #

# %%
#method only for integers

a = 10
b = 15
print("a was {} and b was {}".format(a,b))

a=a+b
b=a-b  # b = a + b - b  == b = a
a=a-b  #a = a + b -a

print("now a is {} and b is {}".format(a,b))
# Out:
# a was 10 and b was 15
# now a is 15 and b is 10

# %% [markdown]
# ## Strings are Arrays
#
# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters.
#
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string.

# %%
a = "Hello World"
print(a[0])
# Out:
# H

# %%
print(a[-1]) #last index
# Out:
# d

# %%
print (a[2] + a[3] + a[4])
# Out:
# llo

# %%
#print(a[k:n]) from index k to index n-1

# %%
print(a[:]) #missing value will take either the starting index or ending index
# Out:
# Hello World

# %%
print(a[0:5])
# Out:
# Hello

# %%
print(a[6:])
# Out:
# World

# %%
print(a[2:-2])
# Out:
# llo Wor

# %% [markdown]
# <a name='concatenation'></a>Combining Strings (Concatenation)
# ---
# It is often very useful to be able to combine strings into a message or page element that we want to display. Again, this is easier to understand through an example.

# %%
first_name = 'Abdul AhAd'
last_name = 'Imtiaz'

full_name = first_name + ' ' + last_name

print((first_name + ' ' + last_name).title())
# Out:
# Abdul Ahad Imtiaz

# %% [markdown]
# The plus sign combines two strings into one, which is called **Concatenation**.

# %% [markdown]
# You can use as many plus signs as you want in composing messages. In fact, many web pages are written as giant strings which are put together through a long series of string concatenations.

# %%
first_name = 'ada'
last_name = 'lovelace'
full_name = first_name + ' ' + last_name
print(full_name)
message = full_name.title()  + " was considered the world's first computer programmer."

print(message)
# Out:
# ada lovelace
# Ada Lovelace was considered the world's first computer programmer.

# %% [markdown]
# <a name='whitespace'></a>Whitespace
# ---
# The term "whitespace" refers to characters that the computer is aware of, but are invisible to readers. The most common whitespace characters are spaces, tabs, and newlines.
#
# Spaces are easy to create, because you have been using them as long as you have been using computers. Tabs and newlines are represented by special character combinations.
#
# The two-character combination "\t" makes a tab appear in a string. Tabs can be used anywhere you like in a string.

# %%
print("Hello everyone!")
# Out:
# Hello everyone!

# %%
print("\tHello everyone!")
# Out:
# 	Hello everyone!

# %%
print("Hello \teveryone!")
# Out:
# Hello 	everyone!

# %% [markdown]
# The combination "\n" makes a newline appear in a string. You can use newlines anywhere you like in a string.

# %%
print("Hello everyone!")
# Out:
# Hello everyone!

# %%
print("\nHello everyone!")
# Out:
# Hello everyone!

# %%
print("Hello \neveryone!")
# Out:
# Hello
# everyone!

# %%
print("\n\n\nHello everyone!")
# Out:
# Hello everyone!

# %%
print("My name is"  " Abdul Ahad Imtiaz")
# Out:
# My name is Abdul Ahad Imtiaz

# %% [markdown]
# ### Stripping whitespace
#
# Many times you will allow users to enter text into a box, and then you will read that text and use it. It is really easy for people to include extra whitespace at the beginning or end of their text. Whitespace includes spaces, tabs, and newlines.
#
# It is often a good idea to strip this whitespace from strings before you start working with them. For example, you might want to let people log in, and you probably want to treat 'eric ' as 'eric' when you are trying to see if I exist on your system.

# %% [markdown]
# You can strip whitespace from the left side, the right side, or both sides of a string.

# %%
name = ' IBA      '

print(name.lstrip())
print(name.rstrip())
print(name.strip())
# Out:
# IBA
#  IBA
# IBA

# %% [markdown]
# It's hard to see exactly what is happening, so maybe the following will make it a little more clear:

# %%
name = ' IBA '
print('-' + name + '-')
print('-' + name.lstrip() + '-')
print('-' + name.rstrip() + '-')
print('-' + name.strip() + '-')
# Out:
# - IBA -
# -IBA -
# - IBA-
# -IBA-

# %% [markdown]
# <a name='integers'></a>Integers
# ---
# You can do all of the basic operations with integers, and everything should behave as you expect. Addition and subtraction use the standard plus and minus symbols. Multiplication uses the asterisk, and division uses a forward slash. Exponents use two asterisks.

# %%
print(3+2)
# Out:
# 5

# %%
print(3-2)
# Out:
# 1

# %%
print(3*2)
# Out:
# 6

# %%
f = 3/2
print(3/2)
type(f)
# Out:
# 1.5
# float

# %%
print(3**2)
# Out:
# 9

# %% [markdown]
# ##### Finding a Remainder

# %%
print(19%5)
# Out:
# 4

# %% [markdown]
# ##### Finding the lowest factor

# %%
print(16//3)
# Out:
# 5

# %% [markdown]
# You can use parenthesis to modify the standard order of operations.

# %%
standard_order = 2+3*4
print(standard_order)
# Out:
# 14

# %%
my_order = (2+3)*4
print(my_order)
# Out:
# 20

# %%
type(my_order)
# Out:
# int

# %% [markdown]
# <a name='floats'></a>Floating-Point numbers
# ---
# Floating-point numbers refer to any number with a decimal point. Most of the time, you can think of floating point numbers as decimals, and they will behave as you expect them to.

# %%
number = 0.1+0.1
print(number)
# Out:
# 0.2

# %%
type(number)
# Out:
# float

# %%
flag = "False"
type(flag)
# Out:
# str

# %% [markdown]
# ## Input from user

# %%
### Example 1

first_name = input('Write First Name: ')

last_name = input('Enter Last Name: ')

print(first_name+' '+last_name)
fn = first_name+' '+last_name
print(fn.title())

# %%
### Example 2

first_number = 15
second_number = 2

# math operations on numeric values
print('addition')
print(first_number + second_number)
print('subtraction')
print(first_number - second_number)
print('multiplication')
print(first_number * second_number)
print('division')
print(first_number / second_number)

result = first_number / second_number
type(result)

# %% [markdown]
# # 3. CONDITIONAL LOGIC

# %% [raw]
# 3 Things to remeber
#
# -> IF
# -> ELIF
# -> ELSE

# %% [markdown]
# ![Screenshot_7.png](attachment:Screenshot_7.png)

# %% [markdown]
# # IF Statement

# %% [raw]
# HOW TO WRITE??
#
# if <expr>:
#     <statement>

# %%
# Example 1


first_number = input('Enter first number: ')
second_number = input('Enter second number: ')
    
if first_number > second_number:
    print('First Number is greater')
# Out:
# Enter first number: 10
# Enter second number: 20

# %% [markdown]
# # IF..ELSE Statements

# %% [raw]
# if <expr>:
#     <statement(s)>
# else:
#     <statement(s)>

# %% [raw]
# Types Casting

# %%
first_number = input('Enter first number: ')
result = int(first_number)
type(result)
# Out:
# Enter first number: 10
# int

# %%
# Example 2

first_number = input('Enter first number: ')
second_number = input('Enter second number: ')
first_number = int(first_number)
second_number = int(second_number)
if first_number > second_number:
    print('First Number is greater')
else:
    print('Second Number is greater')
# Out:
# Enter first number: 10
# Enter second number: 50
# Second Number is greater

# %% [markdown]
# # IF..ELIF..ELSE Statements

# %% [raw]
# if <expr>:
#     <statement(s)>
# elif <expr>:
#     <statement(s)>
# elif <expr>:
#     <statement(s)>
#     ...
# else:
#     <statement(s)>

# %%
# Example 3

a = 50
b= 50

if a>b:
    print('a is greater')
elif a==b:
    print('both are equal')
else:
    print('b is greater')
# Out:
# both are equal

# %%
# Example 4
num = input("Enter a number: ") # input
num = float(num) # typecasts string value into float

if num > 0:
    print("Positive number")

elif num == 0:
    print("Zero")
       
else:
    print("Negative number")
# Out:
# Enter a number: 1.5
# Positive number

# %%
# Example 5

a = 100
b = 50
c = 175
if a > b and c > a:
    print("Both conditions are True")
# Out:
# Both conditions are True

# %%
# Example 6

a = 25
b = 30
c = 40
if a > b or c > a:
    print("One condition is true")
# Out:
# One condition is true

# %% [markdown]
# # ASSIGNMENT

# %% [markdown]
# 1) Take input from user
#
#
# Then make a logic which will identfy whether the defined variable is ODD or EVEN. (Search for MOD operation on google)
#
# Example
#
# Input: 7
#
# Output: "This number 7 is an odd number"
#
# Input: 16
#
# Output: "This number 16 is an even number"
#
# 2) Consider a string called data= "Hi my name is <name> and I am currently doing <degree> from <university>, currently in my <semester_number> semester".
#
# Task3: make 4 variables and take input from user
#     print the result in .title(), .upper(), .lower()
#
# 4 Find w possible way to swap two integers other than those shown above

# %% [markdown]
# # ---- End of Session ----
